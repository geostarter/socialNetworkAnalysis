# %% [markdown]
# https://networkx.github.io/
#
# https://blog.dominodatalab.com/social-network-analysis-with-networkx/

# %%
import networkx as nx
import matplotlib.pyplot as plt
import pandas as pd

# %%
# %matplotlib inline

# %%
Followers_df = pd.read_csv(r"C:\Users\Nic\Documents\socialNetworkAnalysis\TwitterTrans.csv")
Followers_df
# Out:
#                     A                B
# 0          saratunxhi    EriSwissMedia
# 1          saratunxhi   BarkhadKaariye
# 2          saratunxhi   zecariastecle1
# 3          saratunxhi         nuhasi12
# 4          saratunxhi    TassewWondale
# 5          saratunxhi          SAM00OR
# 6          saratunxhi  Ataklti88773620
# 7          saratunxhi       Salin_abyi
# 8          saratunxhi            __8nk
# 9          saratunxhi         JemoAziz
# 10         saratunxhi      allosh_abdu
# 11         saratunxhi     _FerdousAtta
# 12         saratunxhi           zzy_wi
# 13         saratunxhi        aDybrOwn3
# 14         saratunxhi   Tsegay35689644
# 15         saratunxhi         danmarly
# 16         saratunxhi      Eru84705419
# 17         saratunxhi     AfroArabican
# 18         saratunxhi         WediNega
# 19         saratunxhi        seid44355
# 20         saratunxhi    Dawit81320922
# 21         saratunxhi    ZeweldiTadese
# 22         saratunxhi    GhilayNeamin2
# ...

# %%
#https://networkx.github.io/documentation/latest/reference/generated/networkx.convert_matrix.from_pandas_edgelist.html#networkx.convert_matrix.from_pandas_edgelist
edges = nx.from_pandas_edgelist(Followers_df,'A','B')

# %%
print (nx.info(edges))
# Out:
# Name:
# Type: Graph
# Number of nodes: 21881
# Number of edges: 55104
# Average degree:   5.0367

# %%
Followers_df['B'].nunique()
# Out:
# 21881

# %%
draw_edges = nx.draw_networkx_edges(edges, pos=nx.spring_layout(edges))
# Out:
# C:\Users\Nic\Anaconda3\lib\site-packages\networkx\drawing\layout.py:499: RuntimeWarning: invalid value encountered in sqrt
#   distance = np.sqrt((delta**2).sum(axis=0))
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\networkx\drawing\layout.py in fruchterman_reingold_layout(G, k, pos, fixed, iterations, threshold, weight, scale, center, dim, random_state)
#     352                                            iterations, threshold,
# --> 353                                            dim, random_state)
#     354     except:
#
# <decorator-gen-601> in _sparse_fruchterman_reingold(A, k, pos, fixed, iterations, threshold, dim, random_state)
#
# ~\Anaconda3\lib\site-packages\networkx\utils\decorators.py in _random_state(func, *args, **kwargs)
#     386         new_args[random_state_index] = random_state_instance
# ...
